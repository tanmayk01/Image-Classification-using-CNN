# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import tensorflow as tf
import keras
import os

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
##for reaching till the file
path1=r"D:\imarticus\dogcat"
cate=['dog','cat']

# %%
for i in cate:
    folders=os.path.join(path1,i)
    print(folders)
# Out:
# D:\imarticus\dogcat\dog
# D:\imarticus\dogcat\cat

# %%
for i in cate:
    folders = os.path.join(path1 ,i)    ##  code enters the dog folder 
    for image in os.listdir(folders):   ## this will read all images inside the dog folder 
        image_path  = os.path.join(folders , image)
        print(image_path)
# Out:
# D:\imarticus\dogcat\dog\dog1.PNG
# D:\imarticus\dogcat\dog\dog10.PNG
# D:\imarticus\dogcat\dog\dog11.PNG
# D:\imarticus\dogcat\dog\dog12.PNG
# D:\imarticus\dogcat\dog\dog13.PNG
# D:\imarticus\dogcat\dog\dog14.PNG
# D:\imarticus\dogcat\dog\dog15.PNG
# D:\imarticus\dogcat\dog\dog2.png
# D:\imarticus\dogcat\dog\dog3.PNG
# D:\imarticus\dogcat\dog\dog4.PNG
# D:\imarticus\dogcat\dog\dog5.PNG
# D:\imarticus\dogcat\dog\dog6.PNG
# D:\imarticus\dogcat\dog\dog7.PNG
# D:\imarticus\dogcat\dog\dog8.PNG
# D:\imarticus\dogcat\dog\dog9.PNG
# D:\imarticus\dogcat\cat\cat1.png
# D:\imarticus\dogcat\cat\cat10.PNG
# D:\imarticus\dogcat\cat\cat11.PNG
# D:\imarticus\dogcat\cat\cat12.PNG
# D:\imarticus\dogcat\cat\cat13.PNG
# D:\imarticus\dogcat\cat\cat14.PNG
# D:\imarticus\dogcat\cat\cat15.PNG
# D:\imarticus\dogcat\cat\cat2.png
# D:\imarticus\dogcat\cat\cat3.PNG
# D:\imarticus\dogcat\cat\cat4.PNG
# D:\imarticus\dogcat\cat\cat5.PNG
# D:\imarticus\dogcat\cat\cat6.PNG
# D:\imarticus\dogcat\cat\cat7.PNG
# ...

# %%
os.listdir(folders)
# Out:
# ['cat1.png',
#  'cat10.PNG',
#  'cat11.PNG',
#  'cat12.PNG',
#  'cat13.PNG',
#  'cat14.PNG',
#  'cat15.PNG',
#  'cat2.png',
#  'cat3.PNG',
#  'cat4.PNG',
#  'cat5.PNG',
#  'cat6.PNG',
#  'cat7.PNG',
#  'cat8.PNG',
#  'cat9.PNG']

# %%
for i in cate:
    folders = os.path.join(path1 ,i)
    for image in os.listdir(folders):
        image_path  = os.path.join(folders , image)
        image_array =  cv2.imread(image_path)
        plt.imshow(image_array)
        ##above code is for explanation / prrof purpsose

# %%
image_path
# Out:
# 'D:\\imarticus\\dogcat\\cat\\cat9.PNG'

# %%
cv2.imread('D:\\imarticus\\dogcat\\cat\\cat9.PNG')
# Out:
# array([[[116, 125, 104],
#         [117, 127, 104],
#         [117, 128, 103],
#         ...,
#         [207, 219, 219],
#         [205, 217, 217],
#         [205, 217, 217]],
#
#        [[116, 124, 101],
#         [116, 124,  99],
#         [115, 124,  98],
#         ...,
#         [207, 219, 219],
#         [205, 217, 217],
#         [205, 217, 217]],
#
#        [[112, 118,  93],
#         [112, 118,  92],
#         [111, 118,  92],
#         ...,
#         [206, 218, 218],
#         [205, 217, 217],
#         [204, 216, 216]],
#
#        ...,
#
#        [[ 98, 102, 109],
#         [ 95,  99, 107],
#         [ 94,  98, 106],
#         ...,
#         [231, 236, 235],
#         [231, 235, 235],
#         [229, 233, 233]],
#
#        [[104, 109, 112],
#         [101, 106, 110],
#         [ 97, 102, 108],
#         ...,
#         [231, 236, 235],
#         [232, 237, 235],
#         [231, 236, 235]],
#
#        [[105, 110, 111],
#         [104, 109, 110],
#         [101, 106, 110],
# ...

# %%
image_size = 200    #   this 200 is just a number 
path1=r"D:\imarticus\dogcat"
cate = ['dog' ,'cat']  ## so index for this is 0 and 1 
    
input_image = []    
for i in cate:
    folders = os.path.join(path1 ,i)
    label   = cate.index(i)   
    for image in os.listdir(folders):
        image_path  = os.path.join(folders , image)
        image_array =  cv2.imread(image_path)
        plt.imshow(image_array)
        image_array =cv2.resize(image_array , (image_size  , image_size) )
        input_image.append([image_array , label])

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-ac4f6496dcd7> in <module>
# ----> 1 len(label)
#
# TypeError: object of type 'int' has no len()

# %%
input_image[19]
# Out:
# [array([[[184, 207, 200],
#          [184, 207, 200],
#          [185, 204, 200],
#          ...,
#          [206, 214, 210],
#          [207, 215, 212],
#          [208, 217, 214]],
#
#         [[186, 208, 202],
#          [186, 208, 202],
#          [186, 207, 201],
#          ...,
#          [207, 215, 212],
#          [208, 216, 213],
#          [209, 218, 215]],
#
#         [[187, 209, 203],
#          [187, 209, 203],
#          [188, 208, 204],
#          ...,
#          [207, 216, 210],
#          [208, 217, 211],
#          [210, 218, 212]],
#
#         ...,
#
#         [[213, 212, 208],
#          [215, 212, 208],
#          [214, 211, 207],
#          ...,
#          [229, 228, 224],
#          [229, 228, 224],
#          [229, 228, 224]],
#
#         [[215, 212, 208],
#          [213, 212, 208],
#          [213, 212, 208],
#          ...,
#          [229, 228, 224],
#          [229, 228, 224],
#          [229, 228, 224]],
#
#         [[215, 212, 208],
# ...

# %%
np.random.shuffle(input_image)

# %%
np.random.shuffle(input_image)   ## to shuffle the images 
#--------------------------------------------------------

X =   []
Y =  []

for X_values , labels in input_image:
    
    X.append(X_values)
    Y.append(labels)

#--------------------------------------
X = np.array(X)
Y = np.array(Y)

# %%
X.shape ##(30 images,size 200 by 200,RGB since its color)
# Out:
# (30, 200, 200, 3)

# %%
plt.imshow(X[1])

# %%
Y[1]
# Out:
# 1

# %%
X=X/255 ## 255 is highest value of pixels

# %%
## creating a cnn

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout
from keras.utils import to_categorical

# %%
model = Sequential()
model.add(Conv2D(filters = 16 , kernel_size =(3,3) , activation ='relu'    ))
model.add(MaxPool2D(pool_size =(2,2)))

model.add(Flatten())

model.add(Dense(128 , activation = 'relu' , input_shape = X.shape[1:]))

model.add(Dense(2 , activation= 'softmax'))

#----#-------------
model.compile(optimizer='adam', loss = 'sparse_categorical_crossentropy' )
#--------------------
model.fit(X , Y , epochs = 20)
# Out:
# Epoch 1/20
# 1/1 [==============================] - 1s 1s/step - loss: 0.7227
# Epoch 2/20
# 1/1 [==============================] - 0s 402ms/step - loss: 40.1580
# Epoch 3/20
# 1/1 [==============================] - 0s 398ms/step - loss: 6.2366
# Epoch 4/20
# 1/1 [==============================] - 0s 380ms/step - loss: 3.4162
# Epoch 5/20
# 1/1 [==============================] - 0s 379ms/step - loss: 12.1255
# Epoch 6/20
# 1/1 [==============================] - 0s 485ms/step - loss: 8.5727
# Epoch 7/20
# 1/1 [==============================] - 0s 486ms/step - loss: 0.5602
# Epoch 8/20
# 1/1 [==============================] - 0s 382ms/step - loss: 5.1342
# Epoch 9/20
# 1/1 [==============================] - 0s 386ms/step - loss: 1.8894
# Epoch 10/20
# 1/1 [==============================] - 0s 393ms/step - loss: 0.3685
# Epoch 11/20
# 1/1 [==============================] - 0s 384ms/step - loss: 3.3877
# Epoch 12/20
# 1/1 [==============================] - 0s 416ms/step - loss: 2.0666
# ...

# %%
pred=model.predict_classes(X)
# Out:
# C:\Users\tanma\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(pred,Y)
# Out:
# array([[13,  0],
#        [ 2, 15]], dtype=int64)
